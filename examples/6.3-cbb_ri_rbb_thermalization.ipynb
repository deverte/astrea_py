# %% [markdown]
# # (Collisional bound-bound) + (radiative ionization / radiatve recombination + dielectronic recombination) + (radiative bound-bound)

# %%
import numpy as np

import lss

# %%
# spectrum = lss.BlackBodyPlanck()
# spectrum.temperature = 5778.0
# spectrum.total_area = 1367.0

# spectrum = lss.SunGueymard()

spectrum = lss.Kelt9Fossati()

# %%
lss.plot_spectrum(
    spectrum,
    # wavelengths=np.linspace(250, 2500, int(1e3)),
    wavelengths=np.linspace(
        spectrum.min_wavelength,
        spectrum.max_wavelength,
        int(1e3),
    ),
)

# %%
elements = [
    lss.O1Mashonkina(),
    lss.O2Mashonkina(),
]
elements[0].keys = elements[0].all_keys; elements[1].keys = elements[1].all_keys
# elements[0].keys = elements[0].all_keys[:-26]; elements[1].keys = elements[1].all_keys
# elements[0].keys = ["12P3P4", "12P1D4"]; elements[1].keys = ["22P4S"]
# elements[0].keys = ["12P3P4", "13S3S"]; elements[1].keys = ["22P4S"]
# elements[0].keys = ["12P3P4", "12P1D4", "13S3S"]; elements[1].keys = ["22P4S"]

population_nlte_1 = np.zeros(sum([len(el.keys) for el in elements]))
# for i in range(population_nlte_1.shape[0]):
#     population_nlte_1[i] = 1.0 / population_nlte_1.shape[0]
population_nlte_1[0] = 1.0
population_nlte_1[-1] = 1.0
# population_nlte_1[0] = 0.5
# population_nlte_1[1] = 0.5
# population_nlte_1[2] = 0.5
# population_nlte_1[0] = 0.4
# population_nlte_1[1] = 0.1
# population_nlte_1[2] = 0.1
# population_nlte_1[3] = 0.4

# %%
lss.plot_population(
    elements,
    population=population_nlte_1,
    title="Initial electrons population"
)

# %%
lss.plot_b_factor_electron_number_density(
    elements,
    population_nlte_1 = population_nlte_1,
    spectrum = spectrum,
    charge_transfer_elements = [],
    temperature = 1.0e3,
    electron_temperature = 1.0e3,
    electron_number_densities = np.geomspace(1.0e2, 1.0e9, num=int(1e2)),
    optical_depth = 0.0,
    delta_time = 1.0e-2,
    transitions_types = [
        lss.Transition.SE_NIST_O1,
        lss.Transition.CBB_REGEMORTER,
        lss.Transition.PI_MASHONKINA_O1,
        lss.Transition.RR_BADNELL_VERNER,
        # lss.Transition.DR_BADNELL,
        lss.Transition.RBB_TASITSIOMI,
    ],
    legend_1_loc = None,
    legend_2_loc = 'lower left',
    highlight_keys=[
        "12P1D4", # 777.4 nm
    ],
)

# %%
lss.plot_b_factor_electron_number_density(
    elements,
    population_nlte_1 = population_nlte_1,
    spectrum = spectrum,
    charge_transfer_elements = [],
    temperature = 1.0e4,
    electron_temperature = 1.0e4,
    electron_number_densities = np.geomspace(1.0e2, 1.0e9, num=int(1e2)),
    optical_depth = 0.0,
    delta_time = 1.0e-2,
    transitions_types = [
        lss.Transition.SE_NIST_O1,
        lss.Transition.CBB_REGEMORTER,
        lss.Transition.PI_MASHONKINA_O1,
        lss.Transition.RR_BADNELL_VERNER,
        # lss.Transition.DR_BADNELL,
        lss.Transition.RBB_TASITSIOMI,
    ],
    legend_1_loc = None,
    legend_2_loc = 'lower left',
    highlight_keys=[
        "12P1D4", # 777.4 nm
    ],
)

# %%
lss.plot_b_factor_temperature(
    elements,
    population_nlte_1 = population_nlte_1,
    spectrum = spectrum,
    charge_transfer_elements = [],
    temperatures = np.geomspace(1.0e3, 1.0e4, num=int(1e2)),
    electron_number_density = 1.0e2,
    optical_depth = 0.0,
    delta_time = 1.0e-2,
    transitions_types = [
        lss.Transition.SE_NIST_O1,
        lss.Transition.CBB_REGEMORTER,
        lss.Transition.PI_MASHONKINA_O1,
        lss.Transition.RR_BADNELL_VERNER,
        # lss.Transition.DR_BADNELL,
        lss.Transition.RBB_TASITSIOMI,
    ],
    legend_1_loc = None,
    legend_2_loc = 'lower left',
    highlight_keys=[
        "12P1D4", # 777.4 nm
    ],
)

# %%
lss.plot_b_factor_temperature(
    elements,
    population_nlte_1 = population_nlte_1,
    spectrum = spectrum,
    charge_transfer_elements = [],
    temperatures = np.geomspace(1.0e3, 1.0e4, num=int(1e2)),
    electron_number_density = 1.0e5,
    optical_depth = 0.0,
    delta_time = 1.0e-2,
    transitions_types = [
        lss.Transition.SE_NIST_O1,
        lss.Transition.CBB_REGEMORTER,
        lss.Transition.PI_MASHONKINA_O1,
        lss.Transition.RR_BADNELL_VERNER,
        # lss.Transition.DR_BADNELL,
        lss.Transition.RBB_TASITSIOMI,
    ],
    legend_1_loc = None,
    legend_2_loc = 'lower left',
    highlight_keys=[
        "12P1D4", # 777.4 nm
    ],
)

# %%
lss.plot_b_factor_temperature(
    elements,
    population_nlte_1 = population_nlte_1,
    spectrum = spectrum,
    charge_transfer_elements = [],
    temperatures = np.geomspace(1.0e3, 1.0e4, num=int(1e2)),
    electron_number_density = 1.0e9,
    optical_depth = 0.0,
    delta_time = 1.0e-2,
    transitions_types = [
        lss.Transition.SE_NIST_O1,
        lss.Transition.CBB_REGEMORTER,
        lss.Transition.PI_MASHONKINA_O1,
        lss.Transition.RR_BADNELL_VERNER,
        # lss.Transition.DR_BADNELL,
        lss.Transition.RBB_TASITSIOMI,
    ],
    legend_1_loc = None,
    legend_2_loc = 'lower left',
    highlight_keys=[
        "12P1D4", # 777.4 nm
    ],
)
